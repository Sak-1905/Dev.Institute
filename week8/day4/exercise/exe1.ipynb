# %%
class Siamese(cat):
    def __init__(self, name, age, color):
        super().__init__(name, age)
        self.color = color

    def walk(self):
        return f'{self.name} is walking gracefully'

    def sing(self, sounds):
        return f'{sounds} meow'

# Example usage:
my_siamese = Siamese('Mittens', 3, 'blue-point')
print(my_siamese.walk())  # Output: Mittens is walking gracefully
print(my_siamese.sing('Meow'))  # Output: Meow meow
print(f"Is {my_siamese.name} lazy? {my_siamese.is_lazy}")  # Output: Is Mittens lazy? True
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 class Siamese(cat):
#       2     def __init__(self, name, age, color):
#       3         super().__init__(name, age)
#
# NameError: name 'cat' is not defined

# %%
# Code for the class definitions and creating instances (repeated from the previous conversation)
class Pets():
    def __init__(self, animals):
        self.animals = animals

    def walk(self):
        for animal in self.animals:
            print(animal.walk())

class Cat():
    is_lazy = True

    def __init__(self, name, age):
        self.name = name
        self.age = age

    def walk(self):
        return f'{self.name} is just walking around'

class Bengal(Cat):
    def sing(self, sounds):
        return f'{sounds}'

class Chartreux(Cat):
    def sing(self, sounds):
        return f'{sounds}'

class Siamese(Cat):
    def __init__(self, name, age, color):
        super().__init__(name, age)
        self.color = color

    def walk(self):
        return f'{self.name} is walking gracefully'

    def sing(self, sounds):
        return f'{sounds} meow'

# Create instances of each cat breed
bengal_cat = Bengal('Leo', 2)
chartreux_cat = Chartreux('Whiskers', 4)
siamese_cat = Siamese('Mittens', 3, 'blue-point')

# Create a list to hold all the cat instances
all_cats = [bengal_cat, chartreux_cat, siamese_cat]

# Example usage:
for cat in all_cats:
    print(cat.walk())  # Output: Leo is just walking around (for Bengal), Whiskers is just walking around (for Chartreux), Mittens is walking gracefully (for Siamese)
    print(cat.sing('Meow'))  # Output: Meow (for Bengal and Chartreux), Meow meow (for Siamese)
    print(f"Is {cat.name} lazy? {cat.is_lazy}")  # Output: Is Leo lazy? True (for Bengal), Is Whiskers lazy? True (for Chartreux), Is Mittens lazy? True (for Siamese)
# Out:
# Leo is just walking around
# Meow
# Is Leo lazy? True
# Whiskers is just walking around
# Meow
# Is Whiskers lazy? True
# Mittens is walking gracefully
# Meow meow
# Is Mittens lazy? True

# %%
# Code for the class definitions and creating instances (repeated from the previous conversation)
class Pets():
    def __init__(self, animals):
        self.animals = animals

    def walk(self):
        for animal in self.animals:
            print(animal.walk())

class Cat():
    is_lazy = True

    def __init__(self, name, age):
        self.name = name
        self.age = age

    def walk(self):
        return f'{self.name} is just walking around'

class Bengal(Cat):
    def sing(self, sounds):
        return f'{sounds}'

class Chartreux(Cat):
    def sing(self, sounds):
        return f'{sounds}'

class Siamese(Cat):
    def __init__(self, name, age, color):
        super().__init__(name, age)
        self.color = color

    def walk(self):
        return f'{self.name} is walking gracefully'

    def sing(self, sounds):
        return f'{sounds} meow'

# Create instances of each cat breed
bengal_cat = Bengal('Leo', 2)
chartreux_cat = Chartreux('Whiskers', 4)
siamese_cat = Siamese('Mittens', 3, 'blue-point')

# Create a list to hold all the cat instances
all_cats = [bengal_cat, chartreux_cat, siamese_cat]

# Create an instance of the Pets class and pass the all_cats list to it
sara_pets = Pets(all_cats)

# Example usage:
sara_pets.walk()  # Output: Leo is just walking around, Whiskers is just walking around, Mittens is walking gracefully
# Out:
# Leo is just walking around
# Whiskers is just walking around
# Mittens is walking gracefully

# %%
# Code for the class definitions and creating instances (repeated from the previous conversation)
class Pets():
    def __init__(self, animals):
        self.animals = animals

    def walk(self):
        for animal in self.animals:
            print(animal.walk())

class Cat():
    is_lazy = True

    def __init__(self, name, age):
        self.name = name
        self.age = age

    def walk(self):
        return f'{self.name} is just walking around'

class Bengal(Cat):
    def sing(self, sounds):
        return f'{sounds}'

class Chartreux(Cat):
    def sing(self, sounds):
        return f'{sounds}'

class Siamese(Cat):
    def __init__(self, name, age, color):
        super().__init__(name, age)
        self.color = color

    def walk(self):
        return f'{self.name} is walking gracefully'

# Create instances of each cat breed
bengal_cat = Bengal('Leo', 2)
chartreux_cat = Chartreux('Whiskers', 4)
siamese_cat = Siamese('Mittens', 3, 'blue-point')

# Create a list to hold all the cat instances
all_cats = [bengal_cat, chartreux_cat, siamese_cat]

# Create an instance of the Pets class and pass the all_cats list to it
sara_pets = Pets(all_cats)

# Take all the cats for a walk
sara_pets.walk()
# Out:
# Leo is just walking around
# Whiskers is just walking around
# Mittens is walking gracefully
