# %%
class Zoo:
    pass

# %%
class Zoo:
    def __init__(self, zoo_name):
        self.name = zoo_name
        self.animals = []

# %%
# Create a Zoo object named "Central Zoo"
central_zoo = Zoo("Central Zoo")

# Create another Zoo object named "City Zoo"
city_zoo = Zoo("City Zoo")

# Access the name and animals attributes of the zoo objects
print(central_zoo.name)  # Output: Central Zoo
print(central_zoo.animals)  # Output: []

print(city_zoo.name)  # Output: City Zoo
print(city_zoo.animals)  # Output: []
# Out:
# Central Zoo
# []
# City Zoo
# []

# %%
class Zoo:
    def __init__(self, zoo_name):
        self.name = zoo_name
        self.animals = []

    def add_animal(self, new_animal):
        if new_animal not in self.animals:
            self.animals.append(new_animal)
            print(f"{new_animal} has been added to {self.name}'s animal list.")
        else:
            print(f"{new_animal} is already in {self.name}'s animal list.")

# Create a Zoo object named "Central Zoo"
central_zoo = Zoo("Central Zoo")

# Add animals to the Central Zoo
central_zoo.add_animal("Lion")
central_zoo.add_animal("Tiger")
central_zoo.add_animal("Elephant")
central_zoo.add_animal("Lion")  # Trying to add the same animal again

# Print the animals list of the Central Zoo
print(central_zoo.animals)  # Output: ['Lion', 'Tiger', 'Elephant']
# Out:
# Lion has been added to Central Zoo's animal list.
# Tiger has been added to Central Zoo's animal list.
# Elephant has been added to Central Zoo's animal list.
# Lion is already in Central Zoo's animal list.
# ['Lion', 'Tiger', 'Elephant']

# %%
class Zoo:
    def __init__(self, zoo_name):
        self.name = zoo_name
        self.animals = []

    def add_animal(self, new_animal):
        if new_animal not in self.animals:
            self.animals.append(new_animal)
            print(f"{new_animal} has been added to {self.name}'s animal list.")
        else:
            print(f"{new_animal} is already in {self.name}'s animal list.")

    def get_animals(self):
        print(f"All animals in {self.name}'s zoo:")
        for animal in self.animals:
            print(animal)

# Create a Zoo object named "Central Zoo"
central_zoo = Zoo("Central Zoo")

# Add animals to the Central Zoo
central_zoo.add_animal("Lion")
central_zoo.add_animal("Tiger")
central_zoo.add_animal("Elephant")

# Get all animals in the Central Zoo
central_zoo.get_animals()
# Out:
# Lion has been added to Central Zoo's animal list.
# Tiger has been added to Central Zoo's animal list.
# Elephant has been added to Central Zoo's animal list.
# All animals in Central Zoo's zoo:
# Lion
# Tiger
# Elephant

# %%
class Zoo:
    def __init__(self, zoo_name):
        self.name = zoo_name
        self.animals = []

    def add_animal(self, new_animal):
        if new_animal not in self.animals:
            self.animals.append(new_animal)
            print(f"{new_animal} has been added to {self.name}'s animal list.")
        else:
            print(f"{new_animal} is already in {self.name}'s animal list.")

    def get_animals(self):
        print(f"All animals in {self.name}'s zoo:")
        for animal in self.animals:
            print(animal)

    def sell_animal(self, animal_sold):
        if animal_sold in self.animals:
            self.animals.remove(animal_sold)
            print(f"{animal_sold} has been sold from {self.name}'s animal list.")
        else:
            print(f"{animal_sold} is not in {self.name}'s animal list.")

# Create a Zoo object named "Central Zoo"
central_zoo = Zoo("Central Zoo")

# Add animals to the Central Zoo
central_zoo.add_animal("Lion")
central_zoo.add_animal("Tiger")
central_zoo.add_animal("Elephant")

# Get all animals in the Central Zoo
central_zoo.get_animals()

# Sell an animal from the Central Zoo
central_zoo.sell_animal("Tiger")

# Get all animals in the Central Zoo after selling
central_zoo.get_animals()
# Out:
# Lion has been added to Central Zoo's animal list.
# Tiger has been added to Central Zoo's animal list.
# Elephant has been added to Central Zoo's animal list.
# All animals in Central Zoo's zoo:
# Lion
# Tiger
# Elephant
# Tiger has been sold from Central Zoo's animal list.
# All animals in Central Zoo's zoo:
# Lion
# Elephant

# %%
class Zoo:
    def __init__(self, zoo_name):
        self.name = zoo_name
        self.animals = []

    def add_animal(self, new_animal):
        if new_animal not in self.animals:
            self.animals.append(new_animal)
            print(f"{new_animal} has been added to {self.name}'s animal list.")
        else:
            print(f"{new_animal} is already in {self.name}'s animal list.")

    def get_animals(self):
        print(f"All animals in {self.name}'s zoo:")
        for animal in self.animals:
            print(animal)

    def sell_animal(self, animal_sold):
        if animal_sold in self.animals:
            self.animals.remove(animal_sold)
            print(f"{animal_sold} has been sold from {self.name}'s animal list.")
        else:
            print(f"{animal_sold} is not in {self.name}'s animal list.")

    def sort_animals(self):
        sorted_animals = {}
        for animal in sorted(self.animals):
            first_letter = animal[0].upper()
            if first_letter in sorted_animals:
                sorted_animals[first_letter].append(animal)
            else:
                sorted_animals[first_letter] = [animal]
        return sorted_animals

# Create a Zoo object named "Central Zoo"
central_zoo = Zoo("Central Zoo")

# Add animals to the Central Zoo
central_zoo.add_animal("Lion")
central_zoo.add_animal("Tiger")
central_zoo.add_animal("Elephant")
central_zoo.add_animal("Bear")
central_zoo.add_animal("Ape")
central_zoo.add_animal("Cat")
central_zoo.add_animal("Emu")
central_zoo.add_animal("Baboon")
central_zoo.add_animal("Cougar")
central_zoo.add_animal("Eel")

# Sort and group animals in the Central Zoo
sorted_animals = central_zoo.sort_animals()
print(sorted_animals)
# Out:
# Lion has been added to Central Zoo's animal list.
# Tiger has been added to Central Zoo's animal list.
# Elephant has been added to Central Zoo's animal list.
# Bear has been added to Central Zoo's animal list.
# Ape has been added to Central Zoo's animal list.
# Cat has been added to Central Zoo's animal list.
# Emu has been added to Central Zoo's animal list.
# Baboon has been added to Central Zoo's animal list.
# Cougar has been added to Central Zoo's animal list.
# Eel has been added to Central Zoo's animal list.
# {'A': ['Ape'], 'B': ['Baboon', 'Bear'], 'C': ['Cat', 'Cougar'], 'E': ['Eel', 'Elephant', 'Emu'], 'L': ['Lion'], 'T': ['Tiger']}

# %%
class Zoo:
    def __init__(self, zoo_name):
        self.name = zoo_name
        self.animals = []

    def add_animal(self, new_animal):
        if new_animal not in self.animals:
            self.animals.append(new_animal)
            print(f"{new_animal} has been added to {self.name}'s animal list.")
        else:
            print(f"{new_animal} is already in {self.name}'s animal list.")

    def get_animals(self):
        print(f"All animals in {self.name}'s zoo:")
        for animal in self.animals:
            print(animal)

    def sell_animal(self, animal_sold):
        if animal_sold in self.animals:
            self.animals.remove(animal_sold)
            print(f"{animal_sold} has been sold from {self.name}'s animal list.")
        else:
            print(f"{animal_sold} is not in {self.name}'s animal list.")

    def sort_animals(self):
        sorted_animals = {}
        for animal in sorted(self.animals):
            first_letter = animal[0].upper()
            if first_letter in sorted_animals:
                sorted_animals[first_letter].append(animal)
            else:
                sorted_animals[first_letter] = [animal]
        return sorted_animals

    def get_groups(self):
        sorted_animals = self.sort_animals()
        print(f"Groups of animals in {self.name}'s zoo:")
        for first_letter, animals in sorted_animals.items():
            print(f"{first_letter}: {', '.join(animals)}")

# Create a Zoo object named "Central Zoo"
central_zoo = Zoo("Central Zoo")

# Add animals to the Central Zoo
central_zoo.add_animal("Lion")
central_zoo.add_animal("Tiger")
central_zoo.add_animal("Elephant")
central_zoo.add_animal("Bear")
central_zoo.add_animal("Ape")
central_zoo.add_animal("Cat")
central_zoo.add_animal("Emu")
central_zoo.add_animal("Baboon")
central_zoo.add_animal("Cougar")
central_zoo.add_animal("Eel")

# Get groups of animals in the Central Zoo
central_zoo.get_groups()
# Out:
# Lion has been added to Central Zoo's animal list.
# Tiger has been added to Central Zoo's animal list.
# Elephant has been added to Central Zoo's animal list.
# Bear has been added to Central Zoo's animal list.
# Ape has been added to Central Zoo's animal list.
# Cat has been added to Central Zoo's animal list.
# Emu has been added to Central Zoo's animal list.
# Baboon has been added to Central Zoo's animal list.
# Cougar has been added to Central Zoo's animal list.
# Eel has been added to Central Zoo's animal list.
# Groups of animals in Central Zoo's zoo:
# A: Ape
# B: Baboon, Bear
# C: Cat, Cougar
# E: Eel, Elephant, Emu
# L: Lion
# T: Tiger

# %%
class Zoo:
    def __init__(self, zoo_name):
        self.name = zoo_name
        self.animals = []

    def add_animal(self, new_animal):
        if new_animal not in self.animals:
            self.animals.append(new_animal)
            print(f"{new_animal} has been added to {self.name}'s animal list.")
        else:
            print(f"{new_animal} is already in {self.name}'s animal list.")

    def get_animals(self):
        print(f"All animals in {self.name}'s zoo:")
        for animal in self.animals:
            print(animal)

    def sell_animal(self, animal_sold):
        if animal_sold in self.animals:
            self.animals.remove(animal_sold)
            print(f"{animal_sold} has been sold from {self.name}'s animal list.")
        else:
            print(f"{animal_sold} is not in {self.name}'s animal list.")

    def sort_animals(self):
        sorted_animals = {}
        for animal in sorted(self.animals):
            first_letter = animal[0].upper()
            if first_letter in sorted_animals:
                sorted_animals[first_letter].append(animal)
            else:
                sorted_animals[first_letter] = [animal]
        return sorted_animals

    def get_groups(self):
        sorted_animals = self.sort_animals()
        print(f"Groups of animals in {self.name}'s zoo:")
        for first_letter, animals in sorted_animals.items():
            print(f"{first_letter}: {', '.join(animals)}")


# Create a Zoo object named "ramat_gan_safari"
ramat_gan_safari = Zoo("Ramat Gan Safari")

# Add animals to the Ramat Gan Safari
ramat_gan_safari.add_animal("Lion")
ramat_gan_safari.add_animal("Tiger")
ramat_gan_safari.add_animal("Elephant")
ramat_gan_safari.add_animal("Bear")
ramat_gan_safari.add_animal("Giraffe")
ramat_gan_safari.add_animal("Monkey")
ramat_gan_safari.add_animal("Panda")
ramat_gan_safari.add_animal("Kangaroo")
ramat_gan_safari.add_animal("Gorilla")
ramat_gan_safari.add_animal("Zebra")

# Get all animals in the Ramat Gan Safari
ramat_gan_safari.get_animals()

# Sell an animal from the Ramat Gan Safari
ramat_gan_safari.sell_animal("Tiger")

# Get all animals in the Ramat Gan Safari after selling
ramat_gan_safari.get_animals()

# Get groups of animals in the Ramat Gan Safari
ramat_gan_safari.get_groups()
# Out:
# Lion has been added to Ramat Gan Safari's animal list.
# Tiger has been added to Ramat Gan Safari's animal list.
# Elephant has been added to Ramat Gan Safari's animal list.
# Bear has been added to Ramat Gan Safari's animal list.
# Giraffe has been added to Ramat Gan Safari's animal list.
# Monkey has been added to Ramat Gan Safari's animal list.
# Panda has been added to Ramat Gan Safari's animal list.
# Kangaroo has been added to Ramat Gan Safari's animal list.
# Gorilla has been added to Ramat Gan Safari's animal list.
# Zebra has been added to Ramat Gan Safari's animal list.
# All animals in Ramat Gan Safari's zoo:
# Lion
# Tiger
# Elephant
# Bear
# Giraffe
# Monkey
# Panda
# Kangaroo
# Gorilla
# Zebra
# Tiger has been sold from Ramat Gan Safari's animal list.
# All animals in Ramat Gan Safari's zoo:
# Lion
# Elephant
# Bear
# Giraffe
# Monkey
# Panda
# Kangaroo
# Gorilla
# Zebra
# Groups of animals in Ramat Gan Safari's zoo:
# B: Bear
# E: Elephant
# G: Giraffe, Gorilla
# ...
